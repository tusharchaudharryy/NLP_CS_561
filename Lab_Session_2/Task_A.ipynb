# %%
# !pip install python-Levenshtein pandas gdown numpy
# Out:
# Requirement already satisfied: python-Levenshtein in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (0.27.1)
# Collecting pandas
#   Using cached pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting gdown
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy
#   Using cached numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting beautifulsoup4 (from gdown)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting requests[socks] (from gdown)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from gdown)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from beautifulsoup4->gdown) (4.14.1)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown)
#   Using cached charset_normalizer-3.4.3-cp311-cp311-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests[socks]->gdown)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests[socks]->gdown)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\tushar\anaconda3\envs\cs561\lib\site-packages (from tqdm->gdown) (0.4.6)
# Using cached pandas-2.3.1-cp311-cp311-win_amd64.whl (11.3 MB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached numpy-2.3.2-cp311-cp311-win_amd64.whl (13.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp311-cp311-win_amd64.whl (107 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: pytz, urllib3, tzdata, tqdm, soupsieve, PySocks, numpy, idna, filelock, charset_normalizer, certifi, requests, pandas, beautifulsoup4, gdown
#
#    ----------------------------------------  0/15 [pytz]
#    ----------------------------------------  0/15 [pytz]
#    -- -------------------------------------  1/15 [urllib3]
#    ----- ----------------------------------  2/15 [tzdata]
#    ----- ----------------------------------  2/15 [tzdata]
#    ----- ----------------------------------  2/15 [tzdata]
#    -------- -------------------------------  3/15 [tqdm]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ---------------- -----------------------  6/15 [numpy]
#    ------------------ ---------------------  7/15 [idna]
#    -------------------------- ------------- 10/15 [certifi]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    -------------------------------- ------- 12/15 [pandas]
#    ---------------------------------- ----- 13/15 [beautifulsoup4]
#    ---------------------------------------- 15/15 [gdown]
#
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.13.4 certifi-2025.8.3 charset_normalizer-3.4.3 filelock-3.19.1 gdown-5.2.0 idna-3.10 numpy-2.3.2 pandas-2.3.1 pytz-2025.2 requests-2.32.5 soupsieve-2.7 tqdm-4.67.1 tzdata-2025.2 urllib3-2.5.0

# %%
import Levenshtein
import random
import time
import pandas as pd
import numpy as np
import os
import re
import sys

# %%
def load_words_from_local_folder(folder_path='BBC'):
    all_words = []
    if not os.path.isdir(folder_path):
        print(f"Error: Folder not found at '{folder_path}'.")
        return []

    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                    content = f.read()
                    all_words.extend(re.findall(r'\b\w+\b', content.lower()))
            except Exception as e:
                pass
                
    return all_words

# %%
def levenshtein_distance(s1, s2):
    k, c = len(s1), len(s2)
    dp = np.zeros((k + 1, c + 1), dtype=int)
    for i in range(k + 1):
        dp[i][0] = i
    for j in range(c + 1):
        dp[0][j] = j
        
    for i in range(1, k + 1):
        for j in range(1, c + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            dp[i][j] = min(dp[i-1][j] + 1,
                           dp[i][j-1] + 1,
                           dp[i-1][j-1] + cost)
    
    return dp[k][c]

# %%
words = load_words_from_local_folder(folder_path='BBC')
if words:
    pairs = [(random.choice(words), random.choice(words)) for _ in range(100)]

    results = []
    for w1, w2 in pairs:
        start = time.time()
        s1 = levenshtein_distance(w1, w2)
        end = time.time()
        runtime_ours = (end - start) * 1000  

        start = time.time()
        s2 = Levenshtein.distance(w1, w2)
        end = time.time()
        runtime_lib = (end - start) * 1000  

        results.append({
            "Word1": w1,
            "Word2": w2,
            "S1 (Mines)": s1,
            "S2 (Lib)": s2,
            "MED Score Diff": s1 - s2,
            "Runtime Diff (ms)": runtime_ours - runtime_lib
        })

    df = pd.DataFrame(results)
    print("\nComparison of 10 Random Pairs from BBC folder:\n")
    print(df.head(10).to_markdown(index=False))

    print("\nStatistical Summary of Differences:\n")
    print(df[["MED Score Diff", "Runtime Diff (ms)"]].describe().to_markdown())
# Out:
# Comparison of 10 Random Pairs from BBC folder:
#
# | Word1   | Word2    |   S1 (Mines) |   S2 (Lib) |   MED Score Diff |   Runtime Diff (ms) |
# |:--------|:---------|-------------:|-----------:|-----------------:|--------------------:|
# | 30m     | i        |            3 |          3 |                0 |            -34.4732 |
# | would   | the      |            5 |          5 |                0 |              0      |
# | in      | european |            7 |          7 |                0 |              0      |
# | year    | the      |            4 |          4 |                0 |              0      |
# | his     | record   |            6 |          6 |                0 |              0      |
# | in      | call     |            4 |          4 |                0 |              0      |
# | the     | prix     |            4 |          4 |                0 |              0      |
# | in      | s        |            2 |          2 |                0 |              0      |
# | indoor  | and      |            4 |          4 |                0 |              0      |
# | in      | won      |            2 |          2 |                0 |              0      |
#
# Statistical Summary of Differences:
#
# |       |   MED Score Diff |   Runtime Diff (ms) |
# |:------|-----------------:|--------------------:|
# | count |              100 |           100       |
# | mean  |                0 |            -0.27262 |
# | std   |                0 |             3.46668 |
# | min   |                0 |           -34.4732  |
# | 25%   |                0 |             0       |
# | 50%   |                0 |             0       |
# | 75%   |                0 |             0       |
# | max   |                0 |             1.39499 |
